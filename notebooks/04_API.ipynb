# %% [markdown]
# # API Calls with Python

# %% [markdown]
# APIs (application programming interfaces) are hosted on web servers. When you type www.google.com in your browser's address bar, your computer is actually asking the www.google.com server for a webpage, which it then returns to your browser. APIs work much the same way, except instead of your web browser asking for a webpage, your program asks for data. This data is usually returned in JSON format. To retrieve data, we make a request to a webserver. The server then replies with our data. In Python, we'll use the `requests` library to do this.

# %% [markdown]
# ### Python Setup

# %%
# interacting with websites and web-APIs
import requests # easy way to interact with web sites and services

# data manipulation
import pandas as pd # easy data manipulation

# %% [markdown]
# ## How does the request package work?

# %% [markdown]
# We first need to understand what information can be accessed from the API. We use an example of the **PatentsView API** (www.patentsview.org) to make the API call and check the information we get.

# %% [markdown]
# ### About PatentsView API

# %% [markdown]
# The PatentsView platform is built on data derived from the US Patent and Trademark Office (USPTO) bulk data to link inventors, their organizations, locations, and overall patenting activity. The PatentsView API provides programmatic access to longitudinal data and metadata on patents, inventors, companies, and geographic locations since 1976.
#
# To access the API, we use the `request` function. In oder to tell Python what to access we need to specify the url of the API endpoint.
#
# PatentsView has several API endpoints. An endpoint is a server route that is used to retrieve different data from the API. Examples of PatentsView API endpoints: http://www.patentsview.org/api/doc.html
#
# Currently no key is necessary to access the PatentsView API.

# %% [markdown]
# ### Making a Request
# When you ping a website or portal for information this is called making a request. That is exactly what the `requests` library has been designed to do.

# %% [markdown]
# Let's build our first query URL.
#
# **Query String Format**
#
# The query string is always a single JSON object: **{`<field>`:`<value>`}**, where `<field>` is the name of a database field and `<value>` is the value the field will be compared to for equality (Each API Endpoint section contains a list of the data fields that can be selected for inclusion in output datasets).
#
# We use the following base URL for the Patents Endpoint:
#
# **Base URL**: `http://www.patentsview.org/api/patents/query?q={criteria}`

# %% [markdown]
# ## Task example: Pull patents for Stanford University
#
# Let's go to the Patents Endpoint (http://www.patentsview.org/api/patent.html) and find the appropriate field for the organization's name.
#
# The variable that we need is called `"assignee_organization"` (organization name, if assignee is organization)
#
# > _Note_: **Assignee**: the name of the entity - company, foundation, partnership, holding company or individual - that owns the patent. In this example we are looking at universities (organization-level).

# %% [markdown]
# ### Step 1. Build the URL query
#
# Let's build our first URL query by combining the base url with one criterion (name of the `assignee_organization`)
#
# base url: `http://www.patentsview.org/api/patents/query?q=` + criterion: `{"assignee_organization":stanford university"}`

# %%
"""Save the URL as a variable."""

url = 'http://www.patentsview.org/api/patents/query?q={"assignee_organization":"stanford university"}'

# %% [markdown]
# ### Step 2. Get the response

# %% [markdown]
# Now let's get the response using the URL defined above, using the `requests` library.

# %%
"""Get response from the URL."""

r = requests.get(url)

# %% [markdown]
# ### Step 3. Check the Response Code
#
# Before you can do anything with a website or URL in Python, it’s a good idea to check the current status code of said portal.
#
# The following are the response codes for the PatentsView API:
#
# `200` - the query parameters are all valid; the results will be in the body of the response
#
# `400` - the query parameters are not valid, typically either because they are not in valid JSON format, or a specified field or value is not valid; the “status reason” in the header will contain the error message
#
# `500` -  there is an internal error with the processing of the query; the “status reason” in the header will contain the error message

# %% [markdown]
# Let's check the status of our response

# %%
r.status_code  # Check the status code
# Out:
# 200

# %% [markdown]
# We are good to go. Now let's get the content.

# %% [markdown]
# ### Step 4. Get the Content
# After a web server returns a response, you can collect the content you need by converting it into a JSON format.

# %% [markdown]
# JSON is a way to encode data structures like lists and dictionaries to strings that ensures that they are easily readable by machines. JSON is the primary format in which data is passed back and forth to APIs, and most API servers will send their responses in JSON format.

# %%
json = r.json()  # Convert response to JSON format

# %% [markdown]
# By default, we get information on `patent_id`, `patent_number`, and `patent_title`. At the end of the JSON you will see how many results are returned (variable `count`) and the total number of patents found (variable `total_patent_count`).

# %%
json  # View JSON
# Out:
# {'patents': [{'patent_id': '4200770',
#    'patent_number': '4200770',
#    'patent_title': 'Cryptographic apparatus and method'},
#   {'patent_id': '4214918',
#    'patent_number': '4214918',
#    'patent_title': 'Method of forming polycrystalline semiconductor interconnections, resistors and contacts by applying radiation beam'},
#   {'patent_id': '4233671',
#    'patent_number': '4233671',
#    'patent_title': 'Read only memory and integrated circuit and method of programming by laser means'},
#   {'patent_id': '4234352',
#    'patent_number': '4234352',
#    'patent_title': 'Thermophotovoltaic converter and cell for use therein'},
#   {'patent_id': '4325611',
#    'patent_number': '4325611',
#    'patent_title': 'Electrochromic material and electro-optical display using same'},
#   {'patent_id': '4379697',
#    'patent_number': '4379697',
#    'patent_title': 'Stimulator array'},
#   {'patent_id': '4380072',
#    'patent_number': '4380072',
#    'patent_title': 'XUV Laser and method'},
#   {'patent_id': '4404068',
#    'patent_number': '4404068',
#    'patent_title': 'Solid state method for synthesis reactions'},
#   {'patent_id': '4442206',
#    'patent_number': '4442206',
#    'patent_title': 'Method of using isotropic, porous-wall polymeric membrane, hollow-fibers for culture of microbes'},
#   {'patent_id': '4471647',
#    'patent_number': '4471647',
#    'patent_title': 'Gas chromatography system and detector and method'},
#   {'patent_id': '4491760',
#    'patent_number': '4491760',
#    'patent_title': 'Force sensing polymer piezoelectric transducer array'},
#   {'patent_id': '4503533',
#    'patent_number': '4503533',
#    'patent_title': 'Local area communication network utilizing a round robin access scheme with improved channel utilization'},
#   {'patent_id': '4662379',
#    'patent_number': '4662379',
#    'patent_title': 'Coronary artery imaging system using gated tomosynthesis'},
#   {'patent_id': '4665523',
#    'patent_number': '4665523',
#    'patent_title': 'Method and means for error detection and correction in high speed data transmission codes'},
#   {'patent_id': '4665610',
#    'patent_number': '4665610',
#    'patent_title': 'Method of making a semiconductor transducer having multiple level diaphragm structure'},
#   {'patent_id': '4666308',
#    'patent_number': '4666308',
#    'patent_title': 'Method and apparatus for non-destructive testing using acoustic-optic laser probe'},
#   {'patent_id': '4672319',
#    'patent_number': '4672319',
#    'patent_title': 'Multiple pulse excitation in NMR imaging'},
#   {'patent_id': '4674824',
#    'patent_number': '4674824',
#    'patent_title': 'System for enhancement of optical features'},
#   {'patent_id': '4681449',
#    'patent_number': '4681449',
#    'patent_title': 'High speed testing of electronic circuits by electro-optic sampling'},
#   {'patent_id': '4699513',
#    'patent_number': '4699513',
#    'patent_title': 'Distributed sensor and method using coherence multiplexing of fiber-optic interferometric sensors'},
#   {'patent_id': '4700150',
#    'patent_number': '4700150',
#    'patent_title': 'External laser frequency stabilizer'},
#   {'patent_id': '4701006',
#    'patent_number': '4701006',
#    'patent_title': 'Optical-digital hologram recording'},
#   {'patent_id': '4707136',
#    'patent_number': '4707136',
#    'patent_title': 'Gated fiber optic rotation sensor with linearized scale factor'},
#   {'patent_id': '4718424',
#    'patent_number': '4718424',
#    'patent_title': 'NMR imaging of blood flow by moment variation of magnetic gradients'},
#   {'patent_id': '4728192',
#    'patent_number': '4728192',
#    'patent_title': 'Gated fiber optic rotation sensor with extended dynamic range'}],
#  'count': 25,
#  'total_patent_count': 143}

# %% [markdown]
# There are 143 patents for Stanford University, with 25 out of 143 results returned (we will discuss how to change the number of returned results later in the notebook).

# %% [markdown]
# ### Step 5. Convert JSON to a pandas dataframe

# %% [markdown]
# Now let's convert the JSON into a pandas dataframe.

# %%
df = pd.DataFrame(json['patents'])  # Convert to pandas dataframe
df
# Out:
#    patent_id patent_number                                       patent_title
# 0   10002034      10002034  System and method for detecting, collecting, a...
# 1   10004434      10004434  Microfluidic systems for electrochemical trans...
# 2   10012627      10012627  Determining stereoisomeric excess, concentrati...
# 3   10023551      10023551  Glutathione-cleavable prodrug and methods of u...
# 4   10023905      10023905                             Polymerase driven NESA
# 5   10041048      10041048  Immortalization of epithelial cells and method...
# 6   10055502      10055502  System and method for detecting, collecting, a...
# 7   10146705      10146705  System and method for deterring malicious netw...
# 8   10157450      10157450  Enhancing the legibility of images using monoc...
# 9   10160716      10160716  Compounds and methods of use thereof for treat...
# 10  10162940      10162940  System and method of applying state of being t...
# 11  10173978      10173978  Small molecule androgen receptor inhibitors an...
# 12  10175238      10175238                         Markers for abnormal cells
# 13  10221283      10221283  Amino-substituted polysiloxanes combined with ...
# 14  10246739      10246739                          Exonuclease cycling assay
# 15  10266490      10266490                           Radioprotector compounds
# 16  10331644      10331644  Process and framework for facilitating informa...
# 17  10342881      10342881  Manganese-oxo clusters as contrast agents for ...
# 18  10351913      10351913  Compositions and methods for identification of...
# 19  10374198      10374198      Electronic devices with organic nanoparticles
# 20  10376597      10376597  Targeting tumor cells with chemotherapeutic ag...
# 21   4005311       4005311                           Diagnostic X-ray systems
# 22   4044261       4044261  Method and system for improving the definition...
# 23   4263551       4263551  Method and apparatus for identifying conductiv...
# 24   4271706       4271706                                 Ultrasonic scanner

# %% [markdown]
# ### <span style="color:red">Checkpoint 1: Pull patent data for another university</span>

# %% [markdown]
# Now try pulling patent data for Georgetown University:
# - build a query URL;
# - make a request;
# - get the response in JSON format;
# - note the total number of patents;
# - convert the JSON to a pandas dataframe.

# %% [markdown]
# ## Adding to the query other fields of interest

# %% [markdown]
# Above we were able to pull data with the default information on the patents (`patent_id`, `patent_number`, `patent_title`).
#
# What if we want to know about the patent title and patent year?
#
# Let's look for those variables in the API Endpoint (http://www.patentsview.org/api/patent.html), and add those fields to our query.

# %% [markdown]
# To the URL created above, we will add the fields parameter: `&f=["patent_title","patent_year"]`

# %%
url = 'http://www.patentsview.org/api/patents/query?q={"assignee_organization":"stanford university"}&f=["patent_title","patent_year"]'

# %%
r = requests.get(url)  # Get response from the URL
r.status_code  # Check the status code
# Out:
# 200

# %%
json = r.json()  # Convert response to JSON format

# %%
json  # View JSON
# Out:
# {'inventors': [{'inventor_id': '3952833-2',
#    'inventor_first_name': 'Alpheus A.',
#    'inventor_last_name': 'Franklin',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3952837-1',
#    'inventor_first_name': 'Lyman A.',
#    'inventor_last_name': 'Rice',
#    'inventor_lastknown_state': 'WI'},
#   {'inventor_id': '3952838-1',
#    'inventor_first_name': 'John H.',
#    'inventor_last_name': 'Osten',
#    'inventor_lastknown_state': 'WI'},
#   {'inventor_id': '3952838-2',
#    'inventor_first_name': 'Peter D.',
#    'inventor_last_name': 'Ruffalo',
#    'inventor_lastknown_state': 'WI'},
#   {'inventor_id': '3952838-3',
#    'inventor_first_name': 'Donald L.',
#    'inventor_last_name': 'Johnson',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952839-1',
#    'inventor_first_name': 'Patrick R.',
#    'inventor_last_name': 'Brown',
#    'inventor_lastknown_state': 'NC'},
#   {'inventor_id': '3952846-1',
#    'inventor_first_name': 'Chung Ping',
#    'inventor_last_name': 'Han',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3952847-1',
#    'inventor_first_name': 'Hazel H.',
#    'inventor_last_name': 'Via',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3952851-1',
#    'inventor_first_name': 'Guy L.',
#    'inventor_last_name': 'Fougere',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3952851-2',
#    'inventor_first_name': 'Dennis C.',
#    'inventor_last_name': 'Jeffreys',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3952852-1',
#    'inventor_first_name': 'John Charlie',
#    'inventor_last_name': 'Greek, Jr.',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3952852-2',
#    'inventor_first_name': 'Michael Eudell',
#    'inventor_last_name': 'McBride',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3952852-3',
#    'inventor_first_name': 'Howard Carl',
#    'inventor_last_name': 'Tanner',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3952853-1',
#    'inventor_first_name': 'Edward',
#    'inventor_last_name': 'Feldman',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3952855-1',
#    'inventor_first_name': 'James H.',
#    'inventor_last_name': 'Rogers',
#    'inventor_lastknown_state': 'KY'},
#   {'inventor_id': '3952859-2',
#    'inventor_first_name': 'Paul W.',
#    'inventor_last_name': 'Birman, Jr.',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3952862-1',
#    'inventor_first_name': 'Franklin M.',
#    'inventor_last_name': 'McCorkel',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3952864-1',
#    'inventor_first_name': 'William A.',
#    'inventor_last_name': 'Schlagel',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3952867-1',
#    'inventor_first_name': 'William F.',
#    'inventor_last_name': 'McCord',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3952871-1',
#    'inventor_first_name': 'Arlen J.',
#    'inventor_last_name': 'Erickson',
#    'inventor_lastknown_state': 'WA'},
#   {'inventor_id': '3952872-1',
#    'inventor_first_name': 'Peter A.',
#    'inventor_last_name': 'Consiglio, Jr.',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3952875-1',
#    'inventor_first_name': 'Virginia',
#    'inventor_last_name': 'Lombardo',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3952876-1',
#    'inventor_first_name': 'David D.',
#    'inventor_last_name': 'Price, Jr.',
#    'inventor_lastknown_state': 'OK'},
#   {'inventor_id': '3952877-1',
#    'inventor_first_name': 'George F.',
#    'inventor_last_name': 'Kindl',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3952878-1',
#    'inventor_first_name': 'Jack R.',
#    'inventor_last_name': 'Gorham',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952880-1',
#    'inventor_first_name': 'John W.',
#    'inventor_last_name': 'Hill',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952880-2',
#    'inventor_first_name': 'Anthony J.',
#    'inventor_last_name': 'Sword',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952882-1',
#    'inventor_first_name': 'Edwin A.',
#    'inventor_last_name': 'Molitor',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952883-1',
#    'inventor_first_name': 'Stewart A.',
#    'inventor_last_name': 'Phillips',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3952884-1',
#    'inventor_first_name': 'Chester Thomas',
#    'inventor_last_name': 'Babiarz',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3952886-1',
#    'inventor_first_name': 'Edis',
#    'inventor_last_name': 'Hazne',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952887-1',
#    'inventor_first_name': 'David Edward',
#    'inventor_last_name': 'Lutz',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3952889-1',
#    'inventor_first_name': 'William C.',
#    'inventor_last_name': 'Wanker',
#    'inventor_lastknown_state': 'OR'},
#   {'inventor_id': '3952889-2',
#    'inventor_first_name': 'James G.',
#    'inventor_last_name': 'Quinn, Jr.',
#    'inventor_lastknown_state': 'LA'},
#   {'inventor_id': '3952889-3',
#    'inventor_first_name': 'Fred E.',
#    'inventor_last_name': 'Kirby',
#    'inventor_lastknown_state': 'OR'},
#   {'inventor_id': '3952892-1',
#    'inventor_first_name': 'Jack Randall',
#    'inventor_last_name': 'Robinson',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952892-2',
#    'inventor_first_name': 'Roger T.',
#    'inventor_last_name': 'Hilton',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952893-1',
#    'inventor_first_name': 'Joseph J.',
#    'inventor_last_name': 'Kolesar',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3952894-1',
#    'inventor_first_name': 'John',
#    'inventor_last_name': 'Mendez',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952897-1',
#    'inventor_first_name': 'Fred T.',
#    'inventor_last_name': 'Pickerell',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3952897-2',
#    'inventor_first_name': 'Dominic J.',
#    'inventor_last_name': 'Brignola',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3952898-1',
#    'inventor_first_name': 'John W.',
#    'inventor_last_name': 'Bayer',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952899-1',
#    'inventor_first_name': 'Carl W.',
#    'inventor_last_name': 'Cooke',
#    'inventor_lastknown_state': 'CO'},
#   {'inventor_id': '3952901-1',
#    'inventor_first_name': 'Vincent N.',
#    'inventor_last_name': 'Conti',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3952902-1',
#    'inventor_first_name': 'Myron R.',
#    'inventor_last_name': 'Prouty',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952903-1',
#    'inventor_first_name': 'Ellsworth E.',
#    'inventor_last_name': 'Sanders',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3952903-2',
#    'inventor_first_name': 'Elsmer W.',
#    'inventor_last_name': 'Kreeger',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3952905-1',
#    'inventor_first_name': 'Howard J.',
#    'inventor_last_name': 'Rumrill',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3952906-1',
#    'inventor_first_name': 'Thomas',
#    'inventor_last_name': 'Georgopulos',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3952908-1',
#    'inventor_first_name': 'John Reese',
#    'inventor_last_name': 'Carson',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952910-1',
#    'inventor_first_name': 'Richard A.',
#    'inventor_last_name': 'Wheeler',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3952912-1',
#    'inventor_first_name': 'Walter Merton',
#    'inventor_last_name': 'Perry',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3952914-1',
#    'inventor_first_name': 'Kuno J.',
#    'inventor_last_name': 'Vogt',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952916-1',
#    'inventor_first_name': 'Stanley J.',
#    'inventor_last_name': 'Phillips',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3952918-2',
#    'inventor_first_name': 'Edwin W.',
#    'inventor_last_name': 'Wlodyka',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3952919-1',
#    'inventor_first_name': 'John Erik',
#    'inventor_last_name': 'Hansen',
#    'inventor_lastknown_state': 'CO'},
#   {'inventor_id': '3952919-2',
#    'inventor_first_name': 'Joseph M.',
#    'inventor_last_name': 'Magrath',
#    'inventor_lastknown_state': 'NE'},
#   {'inventor_id': '3952919-3',
#    'inventor_first_name': 'Leonard L.',
#    'inventor_last_name': 'Hierath',
#    'inventor_lastknown_state': 'CO'},
#   {'inventor_id': '3952921-1',
#    'inventor_first_name': 'Donald E.',
#    'inventor_last_name': 'Tanner',
#    'inventor_lastknown_state': 'KY'},
#   {'inventor_id': '3952922-1',
#    'inventor_first_name': 'Edwin D.',
#    'inventor_last_name': 'Ditto',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3952922-2',
#    'inventor_first_name': 'A. Hadi',
#    'inventor_last_name': 'Akeel',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3952923-1',
#    'inventor_first_name': 'Thomas P.',
#    'inventor_last_name': 'Tison',
#    'inventor_lastknown_state': 'LA'},
#   {'inventor_id': '3952925-2',
#    'inventor_first_name': 'Mihai A.',
#    'inventor_last_name': 'Bulboaca',
#    'inventor_lastknown_state': 'MO'},
#   {'inventor_id': '3952927-2',
#    'inventor_first_name': 'Robert K.',
#    'inventor_last_name': 'Larson',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3952928-1',
#    'inventor_first_name': 'Charles C.',
#    'inventor_last_name': 'Gerding',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952928-2',
#    'inventor_first_name': 'Louis John',
#    'inventor_last_name': 'Todora',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3952929-1',
#    'inventor_first_name': 'Tibor Joseph',
#    'inventor_last_name': 'Horvath',
#    'inventor_lastknown_state': None},
#   {'inventor_id': '3952931-1',
#    'inventor_first_name': 'Donald R.',
#    'inventor_last_name': 'Weber',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3952934-1',
#    'inventor_first_name': 'Irwin',
#    'inventor_last_name': 'Zahn',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952935-1',
#    'inventor_first_name': 'Kenneth B.',
#    'inventor_last_name': 'ErkenBrack',
#    'inventor_lastknown_state': 'VA'},
#   {'inventor_id': '3952937-1',
#    'inventor_first_name': 'Robert P.',
#    'inventor_last_name': 'Lamons',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3952937-2',
#    'inventor_first_name': 'James Byron',
#    'inventor_last_name': 'Jones',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3952938-1',
#    'inventor_first_name': 'John B.',
#    'inventor_last_name': 'Ulam',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3952939-1',
#    'inventor_first_name': 'William F.',
#    'inventor_last_name': 'Schilling',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3952939-2',
#    'inventor_first_name': 'Adrian M.',
#    'inventor_last_name': 'Beltran',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3952939-3',
#    'inventor_first_name': 'Gerald E.',
#    'inventor_last_name': 'Wasielewski',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952942-1',
#    'inventor_first_name': 'John W.',
#    'inventor_last_name': "O'Leary",
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3952942-2',
#    'inventor_first_name': 'Ralph C.',
#    'inventor_last_name': 'Wicker',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3952942-3',
#    'inventor_first_name': 'John Lewis',
#    'inventor_last_name': 'Williams',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3952947-1',
#    'inventor_first_name': 'Norman B.',
#    'inventor_last_name': 'Saunders',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3952948-1',
#    'inventor_first_name': 'Alfred Dwayne',
#    'inventor_last_name': 'Nelson',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3952948-2',
#    'inventor_first_name': 'Garold L.',
#    'inventor_last_name': 'Goken',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3952949-1',
#    'inventor_first_name': 'Herman K.',
#    'inventor_last_name': 'Dupre',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3952953-1',
#    'inventor_first_name': 'Ralph H.',
#    'inventor_last_name': 'Eby',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952955-1',
#    'inventor_first_name': 'William',
#    'inventor_last_name': 'Clements',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3952956-1',
#    'inventor_first_name': 'James R.',
#    'inventor_last_name': 'Steele',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3952958-1',
#    'inventor_first_name': 'Dennis E.',
#    'inventor_last_name': 'Rich',
#    'inventor_lastknown_state': 'UT'},
#   {'inventor_id': '3952961-1',
#    'inventor_first_name': 'Robert F.',
#    'inventor_last_name': 'Antepenko',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3952964-1',
#    'inventor_first_name': 'Frederic R.',
#    'inventor_last_name': 'Arden',
#    'inventor_lastknown_state': 'NH'},
#   {'inventor_id': '3952965-1',
#    'inventor_first_name': 'Pedro F.',
#    'inventor_last_name': 'Falcon',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3952968-1',
#    'inventor_first_name': 'Richard Bruce',
#    'inventor_last_name': 'McKinstry',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3952969-1',
#    'inventor_first_name': 'James G.',
#    'inventor_last_name': 'Woodier',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3952970-1',
#    'inventor_first_name': 'Casimir T.',
#    'inventor_last_name': 'Orzechowski',
#    'inventor_lastknown_state': 'MD'},
#   {'inventor_id': '3952970-2',
#    'inventor_first_name': 'Nat',
#    'inventor_last_name': 'Seiden',
#    'inventor_lastknown_state': 'MD'},
#   {'inventor_id': '3952971-1',
#    'inventor_first_name': 'Richard T.',
#    'inventor_last_name': 'Whitcomb',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3952973-1',
#    'inventor_first_name': 'Varnell L.',
#    'inventor_last_name': 'James',
#    'inventor_lastknown_state': 'WA'},
#   {'inventor_id': '3952974-1',
#    'inventor_first_name': 'John M.',
#    'inventor_last_name': 'Lang',
#    'inventor_lastknown_state': None},
#   {'inventor_id': '3952975-1',
#    'inventor_first_name': 'Louis L.',
#    'inventor_last_name': 'Laske',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3952976-1',
#    'inventor_first_name': 'James',
#    'inventor_last_name': 'Fletcher',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952976-2',
#    'inventor_first_name': 'Newton D.',
#    'inventor_last_name': 'Brown',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952976-3',
#    'inventor_first_name': 'Gordon L.',
#    'inventor_last_name': 'Jeppesen',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952976-4',
#    'inventor_first_name': 'Nicholas C.',
#    'inventor_last_name': 'Costakos',
#    'inventor_lastknown_state': 'LA'},
#   {'inventor_id': '3952978-1',
#    'inventor_first_name': 'Willard O.',
#    'inventor_last_name': 'Reinitz',
#    'inventor_lastknown_state': 'KY'},
#   {'inventor_id': '3952979-1',
#    'inventor_first_name': 'Siegfried',
#    'inventor_last_name': 'Hansen',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952980-1',
#    'inventor_first_name': 'George L.',
#    'inventor_last_name': 'von Pragenau',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3952980-2',
#    'inventor_first_name': 'Irvin T.',
#    'inventor_last_name': 'Morgan, Jr.',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3952980-3',
#    'inventor_first_name': 'Clifton A.',
#    'inventor_last_name': 'Kirby',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3952981-1',
#    'inventor_first_name': 'Arnold E.',
#    'inventor_last_name': 'Acker',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952982-1',
#    'inventor_first_name': 'David P.',
#    'inventor_last_name': 'Lewis',
#    'inventor_lastknown_state': 'WV'},
#   {'inventor_id': '3952984-1',
#    'inventor_first_name': 'Dracos Alexander',
#    'inventor_last_name': 'Dimitry',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3952985-1',
#    'inventor_first_name': 'Joseph A.',
#    'inventor_last_name': 'Davenport',
#    'inventor_lastknown_state': 'OR'},
#   {'inventor_id': '3952986-1',
#    'inventor_first_name': 'Robert G.',
#    'inventor_last_name': 'Wells',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3952987-1',
#    'inventor_first_name': 'Kenneth A.',
#    'inventor_last_name': 'Bevington',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3952988-1',
#    'inventor_first_name': 'Herbert D.',
#    'inventor_last_name': 'Easterly',
#    'inventor_lastknown_state': 'TN'},
#   {'inventor_id': '3952989-1',
#    'inventor_first_name': 'Constance L.',
#    'inventor_last_name': 'Bannister Hatcher',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3952990-1',
#    'inventor_first_name': 'Onofre S.',
#    'inventor_last_name': 'Garcia',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3952992-1',
#    'inventor_first_name': 'Emil',
#    'inventor_last_name': 'Vyprachticky',
#    'inventor_lastknown_state': 'CO'},
#   {'inventor_id': '3952993-1',
#    'inventor_first_name': 'David E.',
#    'inventor_last_name': 'Roberts',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3952993-2',
#    'inventor_first_name': 'Robert Harold',
#    'inventor_last_name': 'Wind',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3952994-1',
#    'inventor_first_name': 'Michael A.',
#    'inventor_last_name': 'Karr, Jr.',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3952997-1',
#    'inventor_first_name': 'Max D.',
#    'inventor_last_name': 'Whitlock',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3952998-1',
#    'inventor_first_name': 'James',
#    'inventor_last_name': 'Fletcher',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952998-2',
#    'inventor_first_name': 'Thomas R.',
#    'inventor_last_name': 'George, Jr.',
#    'inventor_lastknown_state': 'AK'},
#   {'inventor_id': '3952999-1',
#    'inventor_first_name': 'Charles Robert',
#    'inventor_last_name': 'Keller',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3952999-2',
#    'inventor_first_name': 'William D.',
#    'inventor_last_name': 'Martin',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953000-1',
#    'inventor_first_name': 'William R.',
#    'inventor_last_name': 'Zorbaugh',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953001-1',
#    'inventor_first_name': 'Frederick M.',
#    'inventor_last_name': 'Gleockler',
#    'inventor_lastknown_state': 'MD'},
#   {'inventor_id': '3953001-2',
#    'inventor_first_name': 'Robert G.',
#    'inventor_last_name': 'Gleockler',
#    'inventor_lastknown_state': 'MD'},
#   {'inventor_id': '3953002-1',
#    'inventor_first_name': 'Herbert C.',
#    'inventor_last_name': 'England, Jr.',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3953002-2',
#    'inventor_first_name': 'William C.',
#    'inventor_last_name': 'Voigt, Jr.',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3953006-1',
#    'inventor_first_name': 'Adam J.',
#    'inventor_last_name': 'Patarcity',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953006-2',
#    'inventor_first_name': 'Daniel J.',
#    'inventor_last_name': 'Smith',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953009-1',
#    'inventor_first_name': 'Yih-Renn',
#    'inventor_last_name': 'Kan',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953011-1',
#    'inventor_first_name': 'Paul M.',
#    'inventor_last_name': 'Staehlin',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953011-2',
#    'inventor_first_name': 'William A',
#    'inventor_last_name': 'Nicholas',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953013-1',
#    'inventor_first_name': 'John E.',
#    'inventor_last_name': 'Griffith',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953013-2',
#    'inventor_first_name': 'David D.',
#    'inventor_last_name': 'Grossman',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953013-3',
#    'inventor_first_name': 'Peter M.',
#    'inventor_last_name': 'Will',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953014-1',
#    'inventor_first_name': 'Lester W.',
#    'inventor_last_name': 'Mendell, Jr.',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953015-1',
#    'inventor_first_name': 'John D.',
#    'inventor_last_name': 'Taylor',
#    'inventor_lastknown_state': 'UT'},
#   {'inventor_id': '3953015-2',
#    'inventor_first_name': 'Tommy R.',
#    'inventor_last_name': 'Whitmer',
#    'inventor_lastknown_state': 'OK'},
#   {'inventor_id': '3953016-1',
#    'inventor_first_name': 'Harry C.',
#    'inventor_last_name': 'Gersbacher',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953017-1',
#    'inventor_first_name': 'James C.',
#    'inventor_last_name': 'Wise',
#    'inventor_lastknown_state': 'NC'},
#   {'inventor_id': '3953018-1',
#    'inventor_first_name': 'Bernard John',
#    'inventor_last_name': 'Maopolski',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953020-2',
#    'inventor_first_name': 'Robert G.',
#    'inventor_last_name': 'Kelley',
#    'inventor_lastknown_state': 'UT'},
#   {'inventor_id': '3953025-1',
#    'inventor_first_name': 'Martin S.',
#    'inventor_last_name': 'Mazman',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953026-1',
#    'inventor_first_name': 'William R.',
#    'inventor_last_name': 'Stokely',
#    'inventor_lastknown_state': 'OK'},
#   {'inventor_id': '3953029-1',
#    'inventor_first_name': 'Charles N.',
#    'inventor_last_name': 'Boyd',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953030-1',
#    'inventor_first_name': 'Bruce',
#    'inventor_last_name': 'Muchnick',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953031-1',
#    'inventor_first_name': 'Vernon',
#    'inventor_last_name': 'Kinser',
#    'inventor_lastknown_state': 'MO'},
#   {'inventor_id': '3953032-1',
#    'inventor_first_name': 'Sheldon John',
#    'inventor_last_name': 'Moore',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953032-2',
#    'inventor_first_name': 'Larry S.',
#    'inventor_last_name': 'Day',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953033-1',
#    'inventor_first_name': 'Norman A.',
#    'inventor_last_name': 'Kelly',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3953033-2',
#    'inventor_first_name': 'Norris R.',
#    'inventor_last_name': 'Libert',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3953034-1',
#    'inventor_first_name': 'Rodney L.',
#    'inventor_last_name': 'Nelson',
#    'inventor_lastknown_state': 'AZ'},
#   {'inventor_id': '3953035-1',
#    'inventor_first_name': 'John',
#    'inventor_last_name': 'Beckisk',
#    'inventor_lastknown_state': 'WI'},
#   {'inventor_id': '3953037-1',
#    'inventor_first_name': 'Mason C.',
#    'inventor_last_name': 'Winfield, Jr.',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953038-1',
#    'inventor_first_name': 'Lawrence P.',
#    'inventor_last_name': 'Ludwig',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953039-1',
#    'inventor_first_name': 'Robert Z.',
#    'inventor_last_name': 'Hauge',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953039-2',
#    'inventor_first_name': 'George J.',
#    'inventor_last_name': 'Loos',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953039-3',
#    'inventor_first_name': 'Matthew F.',
#    'inventor_last_name': 'Marsicano',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953040-1',
#    'inventor_first_name': 'Dale H.',
#    'inventor_last_name': 'Unruh',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953040-2',
#    'inventor_first_name': 'Jan B.',
#    'inventor_last_name': 'Yates',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953041-1',
#    'inventor_first_name': 'Herman',
#    'inventor_last_name': 'Buss',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3953042-1',
#    'inventor_first_name': 'Ewald D.',
#    'inventor_last_name': 'Pyzel',
#    'inventor_lastknown_state': 'NV'},
#   {'inventor_id': '3953042-2',
#    'inventor_first_name': 'Harold E.',
#    'inventor_last_name': 'Codding',
#    'inventor_lastknown_state': 'NV'},
#   {'inventor_id': '3953044-1',
#    'inventor_first_name': 'James D.',
#    'inventor_last_name': 'Wilson, II',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953045-1',
#    'inventor_first_name': 'Valentine G.',
#    'inventor_last_name': 'Feret, Jr.',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953047-1',
#    'inventor_first_name': 'Lawrence M.',
#    'inventor_last_name': 'Morgan',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3953048-1',
#    'inventor_first_name': 'George D.',
#    'inventor_last_name': 'Vincent',
#    'inventor_lastknown_state': 'TN'},
#   {'inventor_id': '3953048-2',
#    'inventor_first_name': 'Johnie W.',
#    'inventor_last_name': 'Morris',
#    'inventor_lastknown_state': 'TN'},
#   {'inventor_id': '3953051-1',
#    'inventor_first_name': 'Beulah B.',
#    'inventor_last_name': 'Weathers',
#    'inventor_lastknown_state': 'GA'},
#   {'inventor_id': '3953055-1',
#    'inventor_first_name': 'Allan P.',
#    'inventor_last_name': 'Stark',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953056-1',
#    'inventor_first_name': 'Alvin V.',
#    'inventor_last_name': 'Roberts',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953058-1',
#    'inventor_first_name': 'John W.',
#    'inventor_last_name': 'Soblesky',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953059-2',
#    'inventor_first_name': 'Arthur H.',
#    'inventor_last_name': 'McElroy, II',
#    'inventor_lastknown_state': 'OK'},
#   {'inventor_id': '3953061-1',
#    'inventor_first_name': 'Randall C.',
#    'inventor_last_name': 'Hansen',
#    'inventor_lastknown_state': 'SC'},
#   {'inventor_id': '3953061-2',
#    'inventor_first_name': 'Kenneth J.',
#    'inventor_last_name': 'Miller',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953062-1',
#    'inventor_first_name': 'John F.',
#    'inventor_last_name': 'Maston',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953064-1',
#    'inventor_first_name': 'Warren B.',
#    'inventor_last_name': 'McHenry',
#    'inventor_lastknown_state': 'MD'},
#   {'inventor_id': '3953065-1',
#    'inventor_first_name': 'Edward J.',
#    'inventor_last_name': 'Shannon, Jr.',
#    'inventor_lastknown_state': 'LA'},
#   {'inventor_id': '3953066-1',
#    'inventor_first_name': 'Philip O.',
#    'inventor_last_name': 'Hamilton',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953067-1',
#    'inventor_first_name': 'Richard A.',
#    'inventor_last_name': 'Isola',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953070-1',
#    'inventor_first_name': 'Robert C.',
#    'inventor_last_name': 'Fisher',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3953071-1',
#    'inventor_first_name': 'Kenneth H.',
#    'inventor_last_name': 'Striebel',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3953072-1',
#    'inventor_first_name': 'Salomon',
#    'inventor_last_name': 'Esquivel',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953073-1',
#    'inventor_first_name': 'Wolfram H.',
#    'inventor_last_name': 'Kube',
#    'inventor_lastknown_state': 'CO'},
#   {'inventor_id': '3953074-1',
#    'inventor_first_name': 'Woodrow Wilson',
#    'inventor_last_name': 'Cox',
#    'inventor_lastknown_state': 'NC'},
#   {'inventor_id': '3953075-1',
#    'inventor_first_name': 'Richard S.',
#    'inventor_last_name': 'Bonomo',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953076-1',
#    'inventor_first_name': 'Stanley E.',
#    'inventor_last_name': 'Hurd',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953079-1',
#    'inventor_first_name': 'Milan J.',
#    'inventor_last_name': 'Sebo',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953079-2',
#    'inventor_first_name': 'Roy E.',
#    'inventor_last_name': 'Bartholomew',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953080-1',
#    'inventor_first_name': 'Richard J.',
#    'inventor_last_name': 'Bremer',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953081-1',
#    'inventor_first_name': 'William Roy',
#    'inventor_last_name': 'King',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3953083-1',
#    'inventor_first_name': 'Bruce E.',
#    'inventor_last_name': 'Latvala',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953083-2',
#    'inventor_first_name': 'Marc Alan',
#    'inventor_last_name': 'Karon',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953084-1',
#    'inventor_first_name': 'Rene E.',
#    'inventor_last_name': 'Pittet, Jr.',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953084-2',
#    'inventor_first_name': 'Philip J.',
#    'inventor_last_name': 'Grant',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953085-1',
#    'inventor_first_name': 'Victor',
#    'inventor_last_name': 'Randour',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953086-1',
#    'inventor_first_name': 'Frank R.',
#    'inventor_last_name': 'Chaffin',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953091-1',
#    'inventor_first_name': 'George D.',
#    'inventor_last_name': 'Shults',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3953092-1',
#    'inventor_first_name': 'William J.',
#    'inventor_last_name': 'Cronan',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3953092-2',
#    'inventor_first_name': 'Jerry N.',
#    'inventor_last_name': 'Appling',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3953094-1',
#    'inventor_first_name': 'Leon Henry',
#    'inventor_last_name': 'Brown, Jr.',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953096-1',
#    'inventor_first_name': 'Benjamin Charles',
#    'inventor_last_name': 'Williams',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953098-1',
#    'inventor_first_name': 'Roger P.',
#    'inventor_last_name': 'Avery',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3953098-2',
#    'inventor_first_name': 'William Erich',
#    'inventor_last_name': 'Zerlin',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3953099-1',
#    'inventor_first_name': 'William Dean',
#    'inventor_last_name': 'Wilson',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953100-1',
#    'inventor_first_name': 'Edward K.',
#    'inventor_last_name': 'Feeney',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953101-1',
#    'inventor_first_name': 'Vincent J.',
#    'inventor_last_name': 'Palecek',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953103-1',
#    'inventor_first_name': 'Joseph D.',
#    'inventor_last_name': 'Mathis',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3953104-1',
#    'inventor_first_name': 'Nicholas Joseph',
#    'inventor_last_name': 'Roitz',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953104-2',
#    'inventor_first_name': 'Harold Eugene',
#    'inventor_last_name': 'Steinberg',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953105-1',
#    'inventor_first_name': 'Charles C.',
#    'inventor_last_name': 'Ih',
#    'inventor_lastknown_state': 'DE'},
#   {'inventor_id': '3953110-1',
#    'inventor_first_name': 'Day',
#    'inventor_last_name': 'Charoudi',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3953111-1',
#    'inventor_first_name': 'Ralph W.',
#    'inventor_last_name': 'Fisher',
#    'inventor_lastknown_state': 'MO'},
#   {'inventor_id': '3953111-2',
#    'inventor_first_name': 'George',
#    'inventor_last_name': 'Licis',
#    'inventor_lastknown_state': 'MO'},
#   {'inventor_id': '3953111-3',
#    'inventor_first_name': 'Wayne W.',
#    'inventor_last_name': 'Schurter',
#    'inventor_lastknown_state': 'MO'},
#   {'inventor_id': '3953113-1',
#    'inventor_first_name': 'William A.',
#    'inventor_last_name': 'Shull',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953114-1',
#    'inventor_first_name': 'William T.',
#    'inventor_last_name': 'Bidgood',
#    'inventor_lastknown_state': 'GA'},
#   {'inventor_id': '3953115-1',
#    'inventor_first_name': 'Hollis E.',
#    'inventor_last_name': 'French',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3953117-1',
#    'inventor_first_name': 'Berry A.',
#    'inventor_last_name': 'Cannon',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953118-1',
#    'inventor_first_name': 'Anatoli',
#    'inventor_last_name': 'Brushenko',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953120-1',
#    'inventor_first_name': 'Frank C.',
#    'inventor_last_name': 'Badalich',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953120-2',
#    'inventor_first_name': 'George J.',
#    'inventor_last_name': 'Pawl',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953121-1',
#    'inventor_first_name': 'Louis W.',
#    'inventor_last_name': 'Reichart, Jr.',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953123-1',
#    'inventor_first_name': 'Alexander',
#    'inventor_last_name': 'Jesensky',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3953123-2',
#    'inventor_first_name': 'Kenneth J.',
#    'inventor_last_name': 'Fedesna',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953123-3',
#    'inventor_first_name': 'Thomas V.',
#    'inventor_last_name': 'DeRyke',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953125-1',
#    'inventor_first_name': 'Warren J.',
#    'inventor_last_name': 'Bost',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3953126-1',
#    'inventor_first_name': 'Dong Guen',
#    'inventor_last_name': 'Kim',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953126-2',
#    'inventor_first_name': 'Gary Arnold',
#    'inventor_last_name': 'Dubro',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953127-1',
#    'inventor_first_name': 'Norman C.',
#    'inventor_last_name': 'Ahlquist',
#    'inventor_lastknown_state': 'WA'},
#   {'inventor_id': '3953127-2',
#    'inventor_first_name': 'Alan P.',
#    'inventor_last_name': 'Waggoner',
#    'inventor_lastknown_state': 'WA'},
#   {'inventor_id': '3953127-3',
#    'inventor_first_name': 'Robert J.',
#    'inventor_last_name': 'Charlson',
#    'inventor_lastknown_state': 'WA'},
#   {'inventor_id': '3953129-1',
#    'inventor_first_name': 'Bernard P.',
#    'inventor_last_name': 'Hildebrand',
#    'inventor_lastknown_state': 'WA'},
#   {'inventor_id': '3953132-1',
#    'inventor_first_name': 'Paul F.',
#    'inventor_last_name': 'Michelsen',
#    'inventor_lastknown_state': 'MD'},
#   {'inventor_id': '3953134-1',
#    'inventor_first_name': 'Arthur V.',
#    'inventor_last_name': 'Appel',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953134-2',
#    'inventor_first_name': 'Robert S.',
#    'inventor_last_name': 'Hampton, Jr.',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953134-3',
#    'inventor_first_name': 'Leonard A.',
#    'inventor_last_name': 'Morrison',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953135-1',
#    'inventor_first_name': 'Marilyn',
#    'inventor_last_name': 'Levy',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953135-2',
#    'inventor_first_name': 'Milan',
#    'inventor_last_name': 'Schwartz',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953136-1',
#    'inventor_first_name': 'Clifford C.',
#    'inventor_last_name': 'Hach',
#    'inventor_lastknown_state': 'CO'},
#   {'inventor_id': '3953138-1',
#    'inventor_first_name': 'Harrison W.',
#    'inventor_last_name': 'Hine',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953138-2',
#    'inventor_first_name': 'Veli A.',
#    'inventor_last_name': 'Saarinen',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953141-1',
#    'inventor_first_name': 'Hans W.',
#    'inventor_last_name': 'Koch',
#    'inventor_lastknown_state': 'NC'},
#   {'inventor_id': '3953142-1',
#    'inventor_first_name': 'Connor E.',
#    'inventor_last_name': 'Price',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3953143-3',
#    'inventor_first_name': 'Linn R.',
#    'inventor_last_name': 'Andras',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953144-1',
#    'inventor_first_name': 'Ogden W.',
#    'inventor_last_name': 'Boden',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953145-1',
#    'inventor_first_name': 'Ted L.',
#    'inventor_last_name': 'Teach',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953146-1',
#    'inventor_first_name': 'Brian D.',
#    'inventor_last_name': 'Sowards',
#    'inventor_lastknown_state': 'NC'},
#   {'inventor_id': '3953149-1',
#    'inventor_first_name': 'John G.',
#    'inventor_last_name': 'Henne',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953152-1',
#    'inventor_first_name': 'Anatole J.',
#    'inventor_last_name': 'Sipin',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953153-1',
#    'inventor_first_name': 'Melvin F.',
#    'inventor_last_name': 'Huber',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953153-2',
#    'inventor_first_name': 'Lowell D.',
#    'inventor_last_name': 'Hansen',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953154-1',
#    'inventor_first_name': 'William F.',
#    'inventor_last_name': 'Wanner',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3953156-1',
#    'inventor_first_name': 'Thomas A.',
#    'inventor_last_name': 'Smith',
#    'inventor_lastknown_state': 'MS'},
#   {'inventor_id': '3953158-1',
#    'inventor_first_name': 'Sohan L.',
#    'inventor_last_name': 'Uppal',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3953164-1',
#    'inventor_first_name': 'Joseph',
#    'inventor_last_name': 'Boba',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953164-2',
#    'inventor_first_name': 'Robert P.',
#    'inventor_last_name': 'Conger',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953165-3',
#    'inventor_first_name': 'Sidney L.',
#    'inventor_last_name': 'Vail',
#    'inventor_lastknown_state': 'LA'},
#   {'inventor_id': '3953170-1',
#    'inventor_first_name': 'James O.',
#    'inventor_last_name': 'Webb',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3953172-1',
#    'inventor_first_name': 'Stephen I.',
#    'inventor_last_name': 'Shapiro',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953172-2',
#    'inventor_first_name': 'Gerhard',
#    'inventor_last_name': 'Ertingshausen',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953174-1',
#    'inventor_first_name': 'Harold E.',
#    'inventor_last_name': 'LaBelle, Jr.',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3953175-1',
#    'inventor_first_name': 'Richard P.',
#    'inventor_last_name': 'Pulak',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953176-1',
#    'inventor_first_name': 'Teuvo J.',
#    'inventor_last_name': 'Santala',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3953178-1',
#    'inventor_first_name': 'Niels N.',
#    'inventor_last_name': 'Engel',
#    'inventor_lastknown_state': 'NM'},
#   {'inventor_id': '3953180-1',
#    'inventor_first_name': 'Franklin D.',
#    'inventor_last_name': 'Hoffert',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953180-2',
#    'inventor_first_name': 'Harold H.',
#    'inventor_last_name': 'Stotler',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953182-1',
#    'inventor_first_name': 'Thomas P.',
#    'inventor_last_name': 'Roth',
#    'inventor_lastknown_state': 'TN'},
#   {'inventor_id': '3953184-1',
#    'inventor_first_name': 'William F.',
#    'inventor_last_name': 'Stockford',
#    'inventor_lastknown_state': 'NC'},
#   {'inventor_id': '3953184-2',
#    'inventor_first_name': 'Joseph M.',
#    'inventor_last_name': 'Gamewell',
#    'inventor_lastknown_state': 'NC'},
#   {'inventor_id': '3953186-1',
#    'inventor_first_name': 'Robert E.',
#    'inventor_last_name': 'Howey',
#    'inventor_lastknown_state': 'HI'},
#   {'inventor_id': '3953187-1',
#    'inventor_first_name': 'Richard L.',
#    'inventor_last_name': 'James',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3953188-1',
#    'inventor_first_name': 'Harry A.',
#    'inventor_last_name': 'Fertik',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953190-1',
#    'inventor_first_name': 'Karl H.',
#    'inventor_last_name': 'Lange',
#    'inventor_lastknown_state': None},
#   {'inventor_id': '3953191-1',
#    'inventor_first_name': 'Benny M.',
#    'inventor_last_name': 'Barton',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3953192-1',
#    'inventor_first_name': 'Clive',
#    'inventor_last_name': 'Hodgson',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953192-2',
#    'inventor_first_name': 'George R.',
#    'inventor_last_name': 'Hawkes',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953192-3',
#    'inventor_first_name': 'Marion G.',
#    'inventor_last_name': 'Reed',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953193-1',
#    'inventor_first_name': 'Irwin I.',
#    'inventor_last_name': 'Bessen',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953194-2',
#    'inventor_first_name': 'John A.',
#    'inventor_last_name': 'Campbell',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953194-3',
#    'inventor_first_name': 'Theodore T.',
#    'inventor_last_name': 'Magel',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953196-1',
#    'inventor_first_name': 'Richard F.',
#    'inventor_last_name': 'Obenchain',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953200-1',
#    'inventor_first_name': 'Suk Joong',
#    'inventor_last_name': 'Im',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953200-2',
#    'inventor_first_name': 'James D.',
#    'inventor_last_name': 'Johnston',
#    'inventor_lastknown_state': 'LA'},
#   {'inventor_id': '3953201-1',
#    'inventor_first_name': 'John Randolph',
#    'inventor_last_name': 'Wood',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953201-2',
#    'inventor_first_name': 'Roger N.',
#    'inventor_last_name': 'Wright',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953202-1',
#    'inventor_first_name': 'Robert T.',
#    'inventor_last_name': 'Rasmussen',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953203-1',
#    'inventor_first_name': 'Mitchell W.',
#    'inventor_last_name': 'Haller, Jr.',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953205-1',
#    'inventor_first_name': 'Arthur R.',
#    'inventor_last_name': 'Cox',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3953205-2',
#    'inventor_first_name': 'Gary K.',
#    'inventor_last_name': 'Lewis',
#    'inventor_lastknown_state': 'NM'},
#   {'inventor_id': '3953206-1',
#    'inventor_first_name': 'John W.',
#    'inventor_last_name': 'Weigl',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953207-1',
#    'inventor_first_name': 'Anthony M.',
#    'inventor_last_name': 'Horgan',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953208-1',
#    'inventor_first_name': 'Daniel E.',
#    'inventor_last_name': 'Kane',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953209-1',
#    'inventor_first_name': 'Thomas L.',
#    'inventor_last_name': 'Chase',
#    'inventor_lastknown_state': None},
#   {'inventor_id': '3953213-1',
#    'inventor_first_name': 'Ralph L.',
#    'inventor_last_name': 'Gasper',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953214-1',
#    'inventor_first_name': 'Melvin A.',
#    'inventor_last_name': 'Lipson',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953214-2',
#    'inventor_first_name': 'Dale W.',
#    'inventor_last_name': 'Knoth',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953217-1',
#    'inventor_first_name': 'John',
#    'inventor_last_name': 'Goracke',
#    'inventor_lastknown_state': 'AZ'},
#   {'inventor_id': '3953218-1',
#    'inventor_first_name': 'Edward T.',
#    'inventor_last_name': 'Pollard',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953220-1',
#    'inventor_first_name': 'David M.',
#    'inventor_last_name': 'Miller',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953221-1',
#    'inventor_first_name': 'Frederick F.',
#    'inventor_last_name': 'Lange',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953223-1',
#    'inventor_first_name': 'Thomas J.',
#    'inventor_last_name': 'Doran, Jr.',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953223-2',
#    'inventor_first_name': 'Henry C.',
#    'inventor_last_name': 'Stevens',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953225-1',
#    'inventor_first_name': 'John C.',
#    'inventor_last_name': 'Hovekamp',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953228-1',
#    'inventor_first_name': 'Walter L.',
#    'inventor_last_name': 'Roth',
#    'inventor_lastknown_state': None},
#   {'inventor_id': '3953228-2',
#    'inventor_first_name': 'Gregory C.',
#    'inventor_last_name': 'Farrington',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953234-1',
#    'inventor_first_name': 'Arthur K.',
#    'inventor_last_name': 'Hoffmann',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3953235-1',
#    'inventor_first_name': 'George E.',
#    'inventor_last_name': 'Blomgren',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3953235-2',
#    'inventor_first_name': 'Gerald H.',
#    'inventor_last_name': 'Newman',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3953237-1',
#    'inventor_first_name': 'Sheldon L.',
#    'inventor_last_name': 'Epstein',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953237-2',
#    'inventor_first_name': 'Bernard W.',
#    'inventor_last_name': 'Wessling',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3953239-1',
#    'inventor_first_name': 'George E.',
#    'inventor_last_name': 'Anderson',
#    'inventor_lastknown_state': 'RI'},
#   {'inventor_id': '3953241-2',
#    'inventor_first_name': 'Luciano C.',
#    'inventor_last_name': 'Scala',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953241-3',
#    'inventor_first_name': 'Charles R.',
#    'inventor_last_name': 'Ruffing',
#    'inventor_lastknown_state': 'PA'},
#   {'inventor_id': '3953244-1',
#    'inventor_first_name': 'Raymond D.',
#    'inventor_last_name': 'Prengaman',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3953245-1',
#    'inventor_first_name': 'Paul L.',
#    'inventor_last_name': 'Jackson',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3953248-1',
#    'inventor_first_name': 'Lester G.',
#    'inventor_last_name': 'Coch',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3953251-1',
#    'inventor_first_name': 'Alexander D.',
#    'inventor_last_name': 'Butherus',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953251-2',
#    'inventor_first_name': 'Milton Everett',
#    'inventor_last_name': 'Terry',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3953252-3',
#    'inventor_first_name': 'Vladimir A.',
#    'inventor_last_name': 'Dmitriev',
#    'inventor_lastknown_state': 'MD'},
#   {'inventor_id': '3953255-1',
#    'inventor_first_name': 'Clyde',
#    'inventor_last_name': 'Combs, Jr.',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3953256-1',
#    'inventor_first_name': 'William W.',
#    'inventor_last_name': 'Schwarz',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3953256-2',
#    'inventor_first_name': 'William D.',
#    'inventor_last_name': 'Stephens',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3953257-2',
#    'inventor_first_name': 'Hiram H.',
#    'inventor_last_name': 'Dykes',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3953257-3',
#    'inventor_first_name': 'Bernard J.',
#    'inventor_last_name': 'Alley',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3953260-3',
#    'inventor_first_name': 'Howard W.',
#    'inventor_last_name': 'Gerrish, Jr.',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3953260-4',
#    'inventor_first_name': 'Hans B.',
#    'inventor_last_name': 'Jonassen',
#    'inventor_lastknown_state': 'LA'},
#   {'inventor_id': '3953262-3',
#    'inventor_first_name': 'Pasquale',
#    'inventor_last_name': 'Martignoni',
#    'inventor_lastknown_state': 'AL'},
#   {'inventor_id': '3953264-1',
#    'inventor_first_name': 'Leon L.',
#    'inventor_last_name': 'Wu',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3953265-1',
#    'inventor_first_name': 'Roderick Kermit',
#    'inventor_last_name': 'Hood',
#    'inventor_lastknown_state': 'VT'},
#   {'inventor_id': '3953267-1',
#    'inventor_first_name': 'Wilford',
#    'inventor_last_name': 'Flynn',
#    'inventor_lastknown_state': 'IN'},
# ...
#    'inventor_first_name': 'Charles H.',
#    'inventor_last_name': 'Blake',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954082-1',
#    'inventor_first_name': 'William G.',
#    'inventor_last_name': 'Roller',
#    'inventor_lastknown_state': 'MO'},
#   {'inventor_id': '3954082-2',
#    'inventor_first_name': 'Emery L.',
#    'inventor_last_name': 'West',
#    'inventor_lastknown_state': 'OK'},
#   {'inventor_id': '3954083-1',
#    'inventor_first_name': 'James K.',
#    'inventor_last_name': 'Frostrom',
#    'inventor_lastknown_state': 'TN'},
#   {'inventor_id': '3954084-1',
#    'inventor_first_name': 'Francis J.',
#    'inventor_last_name': 'Cronin',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3954085-1',
#    'inventor_first_name': 'Ernie George',
#    'inventor_last_name': 'Nassimbene',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954086-1',
#    'inventor_first_name': 'Fred',
#    'inventor_last_name': 'Maness',
#    'inventor_lastknown_state': 'KS'},
#   {'inventor_id': '3954087-1',
#    'inventor_first_name': 'William D.',
#    'inventor_last_name': 'Stevens',
#    'inventor_lastknown_state': None},
#   {'inventor_id': '3954087-2',
#    'inventor_first_name': 'Walter P.',
#    'inventor_last_name': 'Gorzegno',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3954089-1',
#    'inventor_first_name': 'Lee Roy',
#    'inventor_last_name': 'Hardesty',
#    'inventor_lastknown_state': 'WI'},
#   {'inventor_id': '3954089-2',
#    'inventor_first_name': 'James Alfred',
#    'inventor_last_name': 'Sharpsteen',
#    'inventor_lastknown_state': 'IA'},
#   {'inventor_id': '3954092-1',
#    'inventor_first_name': 'Mardy',
#    'inventor_last_name': 'Polaner',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3954093-1',
#    'inventor_first_name': 'James C.',
#    'inventor_last_name': 'Hughes, Jr.',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954094-1',
#    'inventor_first_name': 'Charles H.',
#    'inventor_last_name': 'Huebner',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3954094-2',
#    'inventor_first_name': 'Allen G.',
#    'inventor_last_name': 'Schroeder',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3954095-1',
#    'inventor_first_name': 'Kenneth Don',
#    'inventor_last_name': 'Lewis',
#    'inventor_lastknown_state': 'WI'},
#   {'inventor_id': '3954097-1',
#    'inventor_first_name': 'Leon T.',
#    'inventor_last_name': 'Wilson, Jr.',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3954098-1',
#    'inventor_first_name': 'Donald E.',
#    'inventor_last_name': 'Dick',
#    'inventor_lastknown_state': 'CO'},
#   {'inventor_id': '3954098-2',
#    'inventor_first_name': 'Daniel',
#    'inventor_last_name': 'Cooper',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954098-3',
#    'inventor_first_name': 'Ronald E.',
#    'inventor_last_name': 'Hileman',
#    'inventor_lastknown_state': 'NC'},
#   {'inventor_id': '3954099-1',
#    'inventor_first_name': 'Jan',
#    'inventor_last_name': 'Raczkowski',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3954099-2',
#    'inventor_first_name': 'Stefania',
#    'inventor_last_name': 'Raczkowski',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3954101-1',
#    'inventor_first_name': 'How F.',
#    'inventor_last_name': 'Wachspress',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954102-1',
#    'inventor_first_name': 'Robert E.',
#    'inventor_last_name': 'Buuck',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3954104-2',
#    'inventor_first_name': 'Mohamed W.',
#    'inventor_last_name': 'Hammad',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3954105-1',
#    'inventor_first_name': 'Harvey M.',
#    'inventor_last_name': 'Nordby',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954105-3',
#    'inventor_first_name': 'Bremen I.',
#    'inventor_last_name': 'Johnson',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954107-1',
#    'inventor_first_name': 'Sheldon R.',
#    'inventor_last_name': 'Chesky',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954107-2',
#    'inventor_first_name': 'Donald',
#    'inventor_last_name': 'Patience',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954108-1',
#    'inventor_first_name': 'Hugh J.',
#    'inventor_last_name': 'Davis',
#    'inventor_lastknown_state': 'MD'},
#   {'inventor_id': '3954109-1',
#    'inventor_first_name': 'Harish A.',
#    'inventor_last_name': 'Patel',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3954110-1',
#    'inventor_first_name': 'Ernest L.',
#    'inventor_last_name': 'Hutchison',
#    'inventor_lastknown_state': 'AR'},
#   {'inventor_id': '3954113-1',
#    'inventor_first_name': 'James Calvin',
#    'inventor_last_name': 'Bohrer',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3954114-2',
#    'inventor_first_name': 'William G.',
#    'inventor_last_name': 'Crowle',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954116-2',
#    'inventor_first_name': 'Donald S.',
#    'inventor_last_name': 'Cushing',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3954117-1',
#    'inventor_first_name': 'William E.',
#    'inventor_last_name': 'Wallace',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3954118-1',
#    'inventor_first_name': 'Stewart',
#    'inventor_last_name': 'Wilcox',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954121-1',
#    'inventor_first_name': 'George W.',
#    'inventor_last_name': 'Kardos',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3954123-1',
#    'inventor_first_name': 'Milton Donald',
#    'inventor_last_name': 'Duckworth, Jr.',
#    'inventor_lastknown_state': 'MO'},
#   {'inventor_id': '3954124-1',
#    'inventor_first_name': 'Richard E.',
#    'inventor_last_name': 'Self',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954125-1',
#    'inventor_first_name': 'Horst F.',
#    'inventor_last_name': 'Wentzek',
#    'inventor_lastknown_state': 'WI'},
#   {'inventor_id': '3954127-1',
#    'inventor_first_name': 'William E.',
#    'inventor_last_name': 'Doxon',
#    'inventor_lastknown_state': 'KS'},
#   {'inventor_id': '3954128-1',
#    'inventor_first_name': 'James L.',
#    'inventor_last_name': 'Rushing',
#    'inventor_lastknown_state': 'OK'},
#   {'inventor_id': '3954128-2',
#    'inventor_first_name': 'Linda S.',
#    'inventor_last_name': 'Rushing',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954129-1',
#    'inventor_first_name': 'David C.',
#    'inventor_last_name': 'Rudell',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3954129-2',
#    'inventor_first_name': 'Jerry C.',
#    'inventor_last_name': 'Storms',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3954135-1',
#    'inventor_first_name': 'Robert W.',
#    'inventor_last_name': 'Hewlitt',
#    'inventor_lastknown_state': 'IA'},
#   {'inventor_id': '3954139-1',
#    'inventor_first_name': 'Joseph C.',
#    'inventor_last_name': 'Allen',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3954140-1',
#    'inventor_first_name': 'Robert P.',
#    'inventor_last_name': 'Hendrick',
#    'inventor_lastknown_state': 'OK'},
#   {'inventor_id': '3954141-2',
#    'inventor_first_name': 'Charles D.',
#    'inventor_last_name': 'Woodward',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3954142-1',
#    'inventor_first_name': 'Gene C.',
#    'inventor_last_name': 'Broaddus',
#    'inventor_lastknown_state': 'OK'},
#   {'inventor_id': '3954142-2',
#    'inventor_first_name': 'Sherman E.',
#    'inventor_last_name': 'Fredrickson',
#    'inventor_lastknown_state': 'OK'},
#   {'inventor_id': '3954144-1',
#    'inventor_first_name': 'Calvin B.',
#    'inventor_last_name': 'Blair',
#    'inventor_lastknown_state': 'KS'},
#   {'inventor_id': '3954145-1',
#    'inventor_first_name': 'Glenn S.',
#    'inventor_last_name': 'Nesbit',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954146-1',
#    'inventor_first_name': 'Alfred S.',
#    'inventor_last_name': 'Smemo',
#    'inventor_lastknown_state': 'IA'},
#   {'inventor_id': '3954147-1',
#    'inventor_first_name': 'Jesse R.',
#    'inventor_last_name': 'Hollins',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3954150-1',
#    'inventor_first_name': 'Carroll R.',
#    'inventor_last_name': 'Cole',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954150-2',
#    'inventor_first_name': 'Warren L.',
#    'inventor_last_name': 'Ferriell',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954150-4',
#    'inventor_first_name': 'Frederick C.',
#    'inventor_last_name': "O'Neill",
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954151-1',
#    'inventor_first_name': 'Tadeusz',
#    'inventor_last_name': 'Budzich',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3954152-1',
#    'inventor_first_name': 'Ralph M.',
#    'inventor_last_name': 'Duttarer',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3954152-2',
#    'inventor_first_name': 'Richard R.',
#    'inventor_last_name': 'Hushower',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3954154-1',
#    'inventor_first_name': 'John A.',
#    'inventor_last_name': 'Kruppenbach',
#    'inventor_lastknown_state': 'AK'},
#   {'inventor_id': '3954154-2',
#    'inventor_first_name': 'John W.',
#    'inventor_last_name': 'Bedenbender',
#    'inventor_lastknown_state': 'OK'},
#   {'inventor_id': '3954155-1',
#    'inventor_first_name': 'Orlando',
#    'inventor_last_name': 'Guidara',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3954160-1',
#    'inventor_first_name': 'Scott Hamilton',
#    'inventor_last_name': 'Carr',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954163-1',
#    'inventor_first_name': 'Andrew',
#    'inventor_last_name': 'Gabor',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954165-1',
#    'inventor_first_name': 'Clarence A.',
#    'inventor_last_name': 'Snyder',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954167-1',
#    'inventor_first_name': 'Raymond E.',
#    'inventor_last_name': 'Kranz',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954167-2',
#    'inventor_first_name': 'Benjamin M.',
#    'inventor_last_name': 'Starr',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954169-1',
#    'inventor_first_name': 'LaVerne W.',
#    'inventor_last_name': 'Clark',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3954170-1',
#    'inventor_first_name': 'Thomas L.',
#    'inventor_last_name': 'Schlough',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3954171-1',
#    'inventor_first_name': 'Robert K.',
#    'inventor_last_name': 'Chick',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3954171-2',
#    'inventor_first_name': 'Ernest L.',
#    'inventor_last_name': 'Edwards',
#    'inventor_lastknown_state': 'CT'},
#   {'inventor_id': '3954172-1',
#    'inventor_first_name': 'Anthony J.',
#    'inventor_last_name': 'Rinella',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954173-1',
#    'inventor_first_name': 'William E.',
#    'inventor_last_name': 'Eaton',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3954174-1',
#    'inventor_first_name': 'Robert G.',
#    'inventor_last_name': 'Kraus',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3954175-1',
#    'inventor_first_name': 'Richard Storrs',
#    'inventor_last_name': 'Mason',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954179-1',
#    'inventor_first_name': 'John G.',
#    'inventor_last_name': 'Warmath',
#    'inventor_lastknown_state': 'TN'},
#   {'inventor_id': '3954181-1',
#    'inventor_first_name': 'Timothy J.',
#    'inventor_last_name': 'Fries',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3954182-1',
#    'inventor_first_name': 'Wilber C.',
#    'inventor_last_name': 'McEvers',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3954184-1',
#    'inventor_first_name': 'Walter M.',
#    'inventor_last_name': 'Mendenhall',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3954186-1',
#    'inventor_first_name': 'Robert X.',
#    'inventor_last_name': 'Hafele',
#    'inventor_lastknown_state': 'LA'},
#   {'inventor_id': '3954188-1',
#    'inventor_first_name': 'Robert F.',
#    'inventor_last_name': 'Boyle',
#    'inventor_lastknown_state': 'MI'},
#   {'inventor_id': '3954189-1',
#    'inventor_first_name': 'Gail',
#    'inventor_last_name': 'Sherritt',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3954190-1',
#    'inventor_first_name': 'Richard W.',
#    'inventor_last_name': 'Howard',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3954190-2',
#    'inventor_first_name': 'Roman J.',
#    'inventor_last_name': 'Weier',
#    'inventor_lastknown_state': 'MN'},
#   {'inventor_id': '3954191-1',
#    'inventor_first_name': 'Andrew B.',
#    'inventor_last_name': 'Wittkower',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3954191-2',
#    'inventor_first_name': 'Geoffrey',
#    'inventor_last_name': 'Ryding',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3954192-1',
#    'inventor_first_name': 'Max Welton',
#    'inventor_last_name': 'Watts',
#    'inventor_lastknown_state': 'GA'},
#   {'inventor_id': '3954193-1',
#    'inventor_first_name': 'Reginald P.',
#    'inventor_last_name': 'Whittingham',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954196-1',
#    'inventor_first_name': 'John W.',
#    'inventor_last_name': 'Gano',
#    'inventor_lastknown_state': 'OH'},
#   {'inventor_id': '3954197-1',
#    'inventor_first_name': 'Charles W.',
#    'inventor_last_name': 'Dean',
#    'inventor_lastknown_state': 'FL'},
#   {'inventor_id': '3954199-1',
#    'inventor_first_name': 'Russell E.',
#    'inventor_last_name': 'Grove',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954200-1',
#    'inventor_first_name': 'Wilburn C.',
#    'inventor_last_name': 'Willis',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3954201-2',
#    'inventor_first_name': 'Anthony F.',
#    'inventor_last_name': 'Schepis',
#    'inventor_lastknown_state': 'NY'},
#   {'inventor_id': '3954202-1',
#    'inventor_first_name': 'Russell E.',
#    'inventor_last_name': 'Petrick',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954205-1',
#    'inventor_first_name': 'Shelly R.',
#    'inventor_last_name': 'Williams',
#    'inventor_lastknown_state': 'TN'},
#   {'inventor_id': '3954207-1',
#    'inventor_first_name': 'Paul W.',
#    'inventor_last_name': 'Gerding',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3954207-2',
#    'inventor_first_name': 'Donald E.',
#    'inventor_last_name': 'Head',
#    'inventor_lastknown_state': 'IN'},
#   {'inventor_id': '3954208-1',
#    'inventor_first_name': 'Roy N.',
#    'inventor_last_name': 'Brill',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954210-1',
#    'inventor_first_name': 'Randal',
#    'inventor_last_name': 'Luscombe',
#    'inventor_lastknown_state': 'MO'},
#   {'inventor_id': '3954213-1',
#    'inventor_first_name': 'Egil A.',
#    'inventor_last_name': 'Andersen',
#    'inventor_lastknown_state': 'MA'},
#   {'inventor_id': '3954217-1',
#    'inventor_first_name': 'Michael C.',
#    'inventor_last_name': 'Smith',
#    'inventor_lastknown_state': 'TX'},
#   {'inventor_id': '3954219-1',
#    'inventor_first_name': 'Daniel J.',
#    'inventor_last_name': 'Mangini',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3954219-2',
#    'inventor_first_name': 'William J.',
#    'inventor_last_name': 'Mauthe',
#    'inventor_lastknown_state': 'NJ'},
#   {'inventor_id': '3954220-1',
#    'inventor_first_name': 'John Paul',
#    'inventor_last_name': 'Foster',
#    'inventor_lastknown_state': 'IL'},
#   {'inventor_id': '3954221-1',
#    'inventor_first_name': 'Prentice W.',
#    'inventor_last_name': 'Johnson',
#    'inventor_lastknown_state': 'SC'},
#   {'inventor_id': '3954223-1',
#    'inventor_first_name': 'William J.',
#    'inventor_last_name': 'Wichman',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954223-2',
#    'inventor_first_name': 'Richard A.',
#    'inventor_last_name': 'Vander Ploeg',
#    'inventor_lastknown_state': 'CA'},
#   {'inventor_id': '3954224-1',
#    'inventor_first_name': 'Ross W.',
#    'inventor_last_name': 'Colebrook',
#    'inventor_lastknown_state': 'WA'},
#   ...],
#  'count': 10000,
#  'total_inventor_count': 100000}

# %% [markdown]
# ### <span style="color:red">Checkpoint 2: Add other fields</span>

# %% [markdown]
# Try adding other fields of interest. Go to the Patents Endpoint (http://www.patentsview.org/api/patent.html) and pick other 2 fields of interest to add to the query and get the results.

# %% [markdown]
# ## Customize the number of results

# %% [markdown]
# As you have noticed, by default, only 25 results are returned. To change the number of results returned (for example, 50 results), add the option parameter to the query URL: `&o={"per_page":50}`

# %%
url = 'http://www.patentsview.org/api/patents/query?q={"assignee_organization":"stanford university"}&f=["patent_title","patent_year"]&o={"per_page":50}'

# %%
json = r.json()  # Convert response to JSON format

# %% [markdown]
# Now the JSON shows 50 results (as noted in the variable `count` at the bottom of the JSON)

# %%
json
# Out:
# {'patents': [{'patent_title': 'Cryptographic apparatus and method',
#    'patent_year': '1980'},
#   {'patent_title': 'Method of forming polycrystalline semiconductor interconnections, resistors and contacts by applying radiation beam',
#    'patent_year': '1980'},
#   {'patent_title': 'Read only memory and integrated circuit and method of programming by laser means',
#    'patent_year': '1980'},
#   {'patent_title': 'Thermophotovoltaic converter and cell for use therein',
#    'patent_year': '1980'},
#   {'patent_title': 'Electrochromic material and electro-optical display using same',
#    'patent_year': '1982'},
#   {'patent_title': 'Stimulator array', 'patent_year': '1983'},
#   {'patent_title': 'XUV Laser and method', 'patent_year': '1983'},
#   {'patent_title': 'Solid state method for synthesis reactions',
#    'patent_year': '1983'},
#   {'patent_title': 'Method of using isotropic, porous-wall polymeric membrane, hollow-fibers for culture of microbes',
#    'patent_year': '1984'},
#   {'patent_title': 'Gas chromatography system and detector and method',
#    'patent_year': '1984'},
#   {'patent_title': 'Force sensing polymer piezoelectric transducer array',
#    'patent_year': '1985'},
#   {'patent_title': 'Local area communication network utilizing a round robin access scheme with improved channel utilization',
#    'patent_year': '1985'},
#   {'patent_title': 'Coronary artery imaging system using gated tomosynthesis',
#    'patent_year': '1987'},
#   {'patent_title': 'Method and means for error detection and correction in high speed data transmission codes',
#    'patent_year': '1987'},
#   {'patent_title': 'Method of making a semiconductor transducer having multiple level diaphragm structure',
#    'patent_year': '1987'},
#   {'patent_title': 'Method and apparatus for non-destructive testing using acoustic-optic laser probe',
#    'patent_year': '1987'},
#   {'patent_title': 'Multiple pulse excitation in NMR imaging',
#    'patent_year': '1987'},
#   {'patent_title': 'System for enhancement of optical features',
#    'patent_year': '1987'},
#   {'patent_title': 'High speed testing of electronic circuits by electro-optic sampling',
#    'patent_year': '1987'},
#   {'patent_title': 'Distributed sensor and method using coherence multiplexing of fiber-optic interferometric sensors',
#    'patent_year': '1987'},
#   {'patent_title': 'External laser frequency stabilizer',
#    'patent_year': '1987'},
#   {'patent_title': 'Optical-digital hologram recording',
#    'patent_year': '1987'},
#   {'patent_title': 'Gated fiber optic rotation sensor with linearized scale factor',
#    'patent_year': '1987'},
#   {'patent_title': 'NMR imaging of blood flow by moment variation of magnetic gradients',
#    'patent_year': '1988'},
#   {'patent_title': 'Gated fiber optic rotation sensor with extended dynamic range',
#    'patent_year': '1988'},
#   {'patent_title': 'Rapid NMR imaging system', 'patent_year': '1988'},
#   {'patent_title': 'Method for estimating signal source locations and signal parameters using an array of signal sensor pairs',
#    'patent_year': '1988'},
#   {'patent_title': 'Method and means for detecting optically transmitted signals and establishing optical interference pattern between electrodes',
#    'patent_year': '1988'},
#   {'patent_title': 'Switched capacitor function generator',
#    'patent_year': '1988'},
#   {'patent_title': 'Method and means for optical detection of charge density modulation in a semiconductor',
#    'patent_year': '1988'},
#   {'patent_title': 'Variable rate magnetic resonance selective excitation for reducing rf power and specific absorption rate',
#    'patent_year': '1988'},
#   {'patent_title': 'Filtered ultrasonic wave method and apparatus for detecting diseased tissue',
#    'patent_year': '1988'},
#   {'patent_title': 'Method of treating tumors using selective application of heat and radiation',
#    'patent_year': '1988'},
#   {'patent_title': 'Diode pumped low doped Nd .sub.3+ glass laser',
#    'patent_year': '1988'},
#   {'patent_title': 'Endless wire saw having material recovery capability',
#    'patent_year': '1988'},
#   {'patent_title': 'Catheter for treatment of tumors', 'patent_year': '1988'},
#   {'patent_title': 'NMR angiography system and method with immunity to inhomogeneity',
#    'patent_year': '1988'},
#   {'patent_title': 'Programmable complementary transistors',
#    'patent_year': '1988'},
#   {'patent_title': 'Method of welding thermocouples to silicon wafers for temperature monitoring in rapid thermal processing',
#    'patent_year': '1988'},
#   {'patent_title': 'Double heterojunction inversion base transistor',
#    'patent_year': '1989'},
#   {'patent_title': 'Error-minimizing noise-reduction system',
#    'patent_year': '1989'},
#   {'patent_title': 'NMR imaging of moving material using variable spatially selected excitation',
#    'patent_year': '1989'},
#   {'patent_title': 'Electrical cable having improved signal transmission characteristics',
#    'patent_year': '1989'},
#   {'patent_title': 'Reduced noise NMR localization system',
#    'patent_year': '1989'},
#   {'patent_title': 'Self-referencing magnetic resonance spectroscopy system',
#    'patent_year': '1989'},
#   {'patent_title': 'Method of making an integrated scanning tunneling microscope',
#    'patent_year': '1990'},
#   {'patent_title': 'Integrated, microminiature electric to fluidic valve and pressure/flow regulator',
#    'patent_year': '1990'},
#   {'patent_title': 'Millimeter-wave active probe', 'patent_year': '1991'},
#   {'patent_title': 'Apparatus and method for multidimensional characterization of objects in real time',
#    'patent_year': '1991'},
#   {'patent_title': 'Bone/tissue analyzer and method', 'patent_year': '1991'}],
#  'count': 50,
#  'total_patent_count': 143}

# %% [markdown]
# ### <span style="color:red">Checkpoint 3: Customize the number of results</span>

# %% [markdown]
# Try customizing the number of returned results using the options parameter.
#
# **Note**: limit the number of results to no more than 100 during the in-class session, to avoid a heavy simultaneous use of the API (so the queries can run faster).

# %% [markdown]
# ## Optional
#
# Please feel free to explore and practice all available options in the API Query Language section of the PatentsView website (http://www.patentsview.org/api/query-language.html).
